# %%
# !pip install pillow matplotlib numpy scikit-image opencv-python

# %%
from PIL import Image

# Open the image file
img = Image.open("/Users/admin/Downloads/Flowers.jpeg")

# Print image properties
print(img.size)  # width and height in pixels
print(img.mode)  # color mode (RGB, L, etc.)

# Display image
img
# Out:
# (736, 920)
# RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x920>

# %%
import numpy as np

# Convert PIL image to NumPy array
arr = np.array(img)

# Print array information
print(arr.shape)  # (height, width, channels)
print(arr.dtype)  # data type (uint8)
# Out:
# (920, 736, 3)
# uint8

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read image using matplotlib
img_mpl = mpimg.imread("/Users/admin/Downloads/Flowers.jpeg")

# Print shape and data type
print("Image shape:", img_mpl.shape)
print("Data type:", img_mpl.dtype)

# Display the image
plt.imshow(img_mpl)
plt.axis("off")
plt.show()
# Out:
# Image shape: (920, 736, 3)
# Data type: uint8

# %%
"""
Q: Why does Matplotlib treat images as NumPy arrays?

A: Matplotlib uses NumPy arrays for images because:
   - NumPy provides fast mathematical operations
   - Easy to manipulate individual pixels
   - Compatible with other scientific libraries
   - Standard format in Python for numerical data
"""
# Out:
# '\nQ: Why does Matplotlib treat images as NumPy arrays?\n\nA: Matplotlib uses NumPy arrays for images because:\n   - NumPy provides fast mathematical operations\n   - Easy to manipulate individual pixels\n   - Compatible with other scientific libraries\n   - Standard format in Python for numerical data\n'

# %%
from skimage import io, img_as_float

# Read image with scikit-image
img_sk = io.imread("/Users/admin/Downloads/Flowers.jpeg")
print("Original dtype:", img_sk.dtype)
print("Original range:", img_sk.min(), "-", img_sk.max())

# Convert to float format (0-1 range)
img_float = img_as_float(img_sk)

# Print min and max pixel values
print("Float dtype:", img_float.dtype)
print("Min pixel value:", img_float.min())
print("Max pixel value:", img_float.max())

# Display
plt.imshow(img_float)
plt.axis("off")
plt.show()
# Out:
# Original dtype: uint8
# Original range: 0 - 255
# Float dtype: float64
# Min pixel value: 0.0
# Max pixel value: 1.0

# %%
img_mp = mpimg.imread("/Users/admin/Downloads/Flowers.jpeg")
print("Shape:", img_mp.shape)

plt.imshow(img_mp)
plt.axis("off")
# Out:
# Shape: (920, 736, 3)
# (np.float64(-0.5), np.float64(735.5), np.float64(919.5), np.float64(-0.5))

# %%
from skimage import io, img_as_float
import matplotlib.pyplot as plt

# %%
# Read and convert image
img_sk = io.imread("/Users/admin/Downloads/Flowers.jpeg")
img_float = img_as_float(img_sk)

# Print pixel value range
print(img_float.min(), img_float.max())

# Display with colorbar
plt.imshow(img_float)
plt.axis("off")
plt.colorbar()
plt.show()
# Out:
# 0.0 1.0

# %%
import cv2

# %%
gray = cv2.imread("/Users/admin/Downloads/Flowers.jpeg", cv2.IMREAD_GRAYSCALE)
bgr = cv2.imread("/Users/admin/Downloads/Flowers.jpeg")
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 4))   # BONUS

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(rgb)
plt.title("RGB")
plt.axis("off")

plt.show()

# %%
import cv2

# %%
# Read image in grayscale
gray = cv2.imread("/Users/admin/Downloads/Flowers.jpeg", cv2.IMREAD_GRAYSCALE)

# Read image in color (BGR format)
bgr = cv2.imread("/Users/admin/Downloads/Flowers.jpeg")

# Convert BGR to RGB for proper display
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

# Display both grayscale and RGB images
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(rgb)
plt.title("RGB")
plt.axis("off")

plt.show()

# %%
"""
REFLECTION QUESTIONS:

1. Which library did you find easiest to use? Why?
   
   PIL is the easiest because it has simple functions for opening 
   and displaying images. The code is short and easy to understand.
   

2. Which library would you choose for real-time video processing?
   
   I would choose OpenCV because it is very fast and has built-in 
   functions for video capture and processing. It is optimized for 
   real-time applications.
   

3. What is the main difference between RGB and BGR?
   
   RGB stores colors as Red-Green-Blue while BGR stores them as 
   Blue-Green-Red. OpenCV uses BGR format, so we need to convert 
   it to RGB when displaying with matplotlib, otherwise colors 
   look wrong (red becomes blue).
"""
# Out:
# '\nREFLECTION QUESTIONS:\n\n1. Which library did you find easiest to use? Why?\n\n   PIL is the easiest because it has simple functions for opening \n   and displaying images. The code is short and easy to understand.\n\n\n2. Which library would you choose for real-time video processing?\n\n   I would choose OpenCV because it is very fast and has built-in \n   functions for video capture and processing. It is optimized for \n   real-time applications.\n\n\n3. What is the main difference between RGB and BGR?\n\n   RGB stores colors as Red-Green-Blue while BGR stores them as \n   Blue-Green-Red. OpenCV uses BGR format, so we need to convert \n   it to RGB when displaying with matplotlib, otherwise colors \n   look wrong (red becomes blue).\n'
